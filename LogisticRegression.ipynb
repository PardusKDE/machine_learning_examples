# %%
import tensorflow as tf
import pandas as pd

# %%
 import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
csv = pd.read_csv("house.csv")

# %%
csv
# Out:
#              date            area  ...  no_of_crimes borough_flag
# 0      1995-01-01  city of london  ...           NaN            1
# 1      1995-02-01  city of london  ...           NaN            1
# 2      1995-03-01  city of london  ...           NaN            1
# 3      1995-04-01  city of london  ...           NaN            1
# 4      1995-05-01  city of london  ...           NaN            1
# ...           ...             ...  ...           ...          ...
# 13544  2019-09-01         england  ...           NaN            0
# 13545  2019-10-01         england  ...           NaN            0
# 13546  2019-11-01         england  ...           NaN            0
# 13547  2019-12-01         england  ...           NaN            0
# 13548  2020-01-01         england  ...           NaN            0
#
# [13549 rows x 7 columns]

# %%
X = np.array(csv["average_price"])
y = np.array(csv["borough_flag"])

# %%
 
plt.style.use("ggplot")
plt.scatter(X, y)
plt.xlabel("Num")
plt.ylabel("Price")
plt.show()

# %%
a, b = np.polyfit(X, y, 1)

# %%
yp = a + b**1 * X**1 + b**2 * X**2

# %%
yp
# Out:
# array([2.54066868e+09, 2.05289348e+09, 1.90184443e+09, ...,
#        1.87624644e+10, 1.90496929e+10, 1.85877177e+10])

# %%
pre1 = np.poly1d(yp)

# %%
plt.hist(pre1)
plt.ylabel("Sayi")
plt.xlabel("Sinif")
plt.show()

# %%
plt.hist(y)
plt.show()
